# %% [markdown]
# ##  1. Import Libraries

# %%
 ! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: numpy in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from xgboost) (1.14.1)

# %%
 ! pip install sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (2.232.2)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (23.2.0)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (1.35.33)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: docker in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (7.1.0)
# Requirement already satisfied: google-pasta in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (6.11.0)
# Requirement already satisfied: jsonschema in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (4.23.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (24.1)
# Requirement already satisfied: pandas in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: pathos in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (0.3.3)
# Requirement already satisfied: platformdirs in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (4.3.6)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sagemaker) (4.25.5)
# Requirement already satisfied: psutil in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sagemaker) (6.0.0)
# Requirement already satisfied: pyyaml~=6.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sagemaker) (6.0.2)
# Requirement already satisfied: requests in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (1.0.10)
# Requirement already satisfied: sagemaker-mlflow in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (0.1.0)
# Requirement already satisfied: schema in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (3.0.0)
# Requirement already satisfied: tqdm in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (4.66.5)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: botocore<1.36.0,>=1.35.33 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.35.33)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.20.2)
# Requirement already satisfied: pydantic<3.0.0,>=1.7.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.9.2)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (13.9.2)
# Requirement already satisfied: mock<5.0,>4.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from jsonschema->sagemaker) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from jsonschema->sagemaker) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from jsonschema->sagemaker) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from requests->sagemaker) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: six in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pandas->sagemaker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pandas->sagemaker) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pandas->sagemaker) (2024.2)
# Requirement already satisfied: ppft>=1.7.6.9 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pathos->sagemaker) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pathos->sagemaker) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pathos->sagemaker) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pathos->sagemaker) (0.70.17)
# Requirement already satisfied: mlflow>=2.8 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from sagemaker-mlflow->sagemaker) (2.16.2)
# Requirement already satisfied: mlflow-skinny==2.16.2 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.16.2)
# Requirement already satisfied: Flask<4 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.13.3)
# Requirement already satisfied: graphene<4 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.3)
# Requirement already satisfied: markdown<4,>=3.3 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.7)
# Requirement already satisfied: matplotlib<4 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.9.2)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.5.2)
# Requirement already satisfied: scipy<2 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.0.35)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Requirement already satisfied: gunicorn<24 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (23.0.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (8.1.7)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.33.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.43)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.27.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.18.0)
# Requirement already satisfied: Mako in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.3.5)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.8.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.2.4)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (9.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from Jinja2<4,>=2.11->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.1)
# Requirement already satisfied: google-auth~=2.0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.35.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.0.11)
# Requirement already satisfied: deprecated>=1.2.6 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.48b0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/slumio/flight-price-prediction/my_env/lib64/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/slumio/flight-price-prediction/my_env/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.6.1)

# %%
import os

import pickle

import boto3

import xgboost as xgb

import numpy as np
import pandas as pd

import sklearn

from sklearn.metrics import r2_score

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
	OneHotEncoder,
	OrdinalEncoder,
	StandardScaler,
	MinMaxScaler,
	PowerTransformer,
	FunctionTransformer
)

from feature_engine.outliers import Winsorizer
from feature_engine.datetime import DatetimeFeatures
from feature_engine.selection import SelectBySingleFeaturePerformance
from feature_engine.encoding import (
	RareLabelEncoder,
	MeanEncoder,
	CountFrequencyEncoder
)

import sagemaker
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput
from sagemaker.tuner import (
    IntegerParameter,
    ContinuousParameter,
    HyperparameterTuner
)

import warnings

# needs after step 5

import sagemaker
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput
from sagemaker.tuner import (
    IntegerParameter,
    ContinuousParameter,
    HyperparameterTuner
)

# %% [markdown]
# ## 2. Display Settings

# %%
pd.set_option('display.max_columns', None)

# %%
sklearn.set_config(transform_output='pandas')

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Read Datasets

# %%
train = pd.read_csv('/home/slumio/flight-price-prediction/data/train.csv')
train.head()
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0       Indigo      2019-06-09   Kolkata    Banglore       NaN     10:20:00
# 1  Jet Airways      2019-05-09   Kolkata    Banglore       NaN          NaN
# 2       Indigo      2019-06-18     Delhi      Cochin       NaN     08:50:00
# 3  Jet Airways      2019-03-15  Banglore   New Delhi       NaN     15:15:00
# 4      Vistara      2019-06-21     Delhi      Cochin       NaN     09:10:00
#
#    duration  total_stops              additional_info  price
# 0       240          1.0                      No Info   4226
# 1       730          1.0  In-flight meal not included   9663
# 2       195          0.0                      No Info   5000
# 3       435          1.0  In-flight meal not included   9134
# 4       190          0.0                      No Info   6216

# %%
val = pd.read_csv('/home/slumio/flight-price-prediction/data/valid.csv')

val
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-03-21  Banglore   New Delhi       NaN
# 1          Jet Airways      2019-06-27     Delhi      Cochin       NaN
# 2               Indigo      2019-06-01    Mumbai   Hyderabad       NaN
# 3               Indigo      2019-04-15     Delhi      Cochin       NaN
# 4    Multiple Carriers      2019-05-21     Delhi      Cochin       NaN
# ..                 ...             ...       ...         ...       ...
# 155        Jet Airways      2019-06-09     Delhi      Cochin       NaN
# 156             Indigo      2019-06-21  Banglore       Delhi       NaN
# 157  Multiple Carriers      2019-05-09     Delhi      Cochin       NaN
# 158        Jet Airways      2019-06-09   Kolkata    Banglore       NaN
# 159             Indigo      2019-05-27  Banglore       Delhi       NaN
#
#     arrival_time  duration  total_stops              additional_info  price
# 0            NaN       840          1.0  In-flight meal not included   7832
# 1       19:00:00       810          2.0  In-flight meal not included  11507
# 2       04:05:00        90          0.0                      No Info   3175
# 3       12:10:00       425          1.0                      No Info   6287
# 4            NaN       625          2.0                      No Info  16655
# ..           ...       ...          ...                          ...    ...
# 155          NaN      1425          1.0  In-flight meal not included  10577
# 156     21:20:00       185          0.0                      No Info   4990
# 157          NaN       625          2.0                      No Info  18191
# 158     23:35:00      1025          1.0                      No Info  14571
# 159     10:05:00       175          0.0                      No Info   4823
#
# [160 rows x 10 columns]

# %%
test = pd.read_csv('/home/slumio/flight-price-prediction/data/test.csv')
test
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-03-09     Delhi      Cochin       NaN
# 1    Multiple Carriers      2019-05-27     Delhi      Cochin       NaN
# 2          Jet Airways      2019-05-21   Kolkata    Banglore       NaN
# 3          Jet Airways      2019-03-21    Mumbai   Hyderabad       NaN
# 4             Air Asia      2019-05-27     Delhi      Cochin       NaN
# ..                 ...             ...       ...         ...       ...
# 195        Jet Airways      2019-06-27     Delhi      Cochin       NaN
# 196        Jet Airways      2019-05-09     Delhi      Cochin       NaN
# 197        Jet Airways      2019-03-03     Delhi      Cochin       NaN
# 198             Indigo      2019-03-12   Chennai     Kolkata       NaN
# 199        Jet Airways      2019-03-06  Banglore   New Delhi       NaN
#
#     arrival_time  duration  total_stops              additional_info  price
# 0            NaN      1275          2.0                      No Info  14851
# 1            NaN       480          1.0                      No Info  13377
# 2       17:35:00       435          1.0                      No Info   8355
# 3       08:35:00        85          0.0  In-flight meal not included   4160
# 4       15:45:00       470          1.0                      No Info   6451
# ..           ...       ...          ...                          ...    ...
# 195     19:00:00       300          1.0                      No Info  14714
# 196          NaN      1355          1.0  In-flight meal not included  12373
# 197     18:50:00       535          1.0                      No Info  18550
# 198     15:35:00       135          0.0                      No Info   6297
# 199          NaN      1290          1.0                      No Info  17471
#
# [200 rows x 10 columns]

# %% [markdown]
# # 4. Preprocessing Operations

# %%
# airline
air_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('grouper', RareLabelEncoder(tol=0.1, n_categories=2, replace_with='Other')),
    ('encoder', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
     
])

# date of journey
feature_to_extract = ['month', 'week', 'day_of_week', 'day_of_month', 'day_of_year']

doj_transformer = Pipeline(steps=[
    ('dt', DatetimeFeatures(features_to_extract=feature_to_extract, yearfirst=True, format='mixed')),
    ('scaler', MinMaxScaler())
])

# source and destination
location_pipe1 = Pipeline(steps=[
    ('grouper', RareLabelEncoder(tol=0.1,replace_with='Other', n_categories=2)),
    ('encoer' , MeanEncoder()),
    ('scaler' , PowerTransformer())
])

def is_north(X):
    columns = X.columns.to_list()
    north_cities = ['Delhi', 'New Delhi', 'Kolkata', 'Mumbai']
    return (
        X.assign(**{
            f"{col}_is_north": X.loc[:, col].isin(north_cities).astype(int)
            for col in columns
        })
        .drop(columns=columns)
    )

location_transformer=FeatureUnion(transformer_list=[
    ('part1', location_pipe1),
    ('part2', FunctionTransformer(func=is_north))
])

# dep_time & arrival_time

time_pipe1 = Pipeline(steps=[
    ('dt', DatetimeFeatures(features_to_extract=['hour','minute'])),
    ('scaler', MinMaxScaler())
])

def part_of_day(X, morning=4, noon=12, evening=16, night=20):
    columns = X.columns.to_list()
    X_temp  = X.assign(**{
        col: pd.to_datetime(X.loc[:, col]).dt.hour for col in columns
    })
    return (
        X_temp
        .assign(**{
            f"{col}_part_of_day": np.select(
                [X_temp.loc[:, col].between(morning, noon, inclusive='left'),
                 X_temp.loc[:, col].between(noon, evening, inclusive='left'),
                 X_temp.loc[:, col].between(evening, night, inclusive='left')
                ],
                ['morning', 'afternoon', 'evening'],
                default='night'
            ) 
            for col in columns
        })
        .drop(columns=columns)
    )

time_pipe2 = Pipeline(steps=[
    ('part', FunctionTransformer(func=part_of_day)),
    ('encoder', CountFrequencyEncoder()),
    ('scaler' , MinMaxScaler())
])


time_transformer = FeatureUnion(transformer_list=[
    ('part1', time_pipe1),
    ('part2', time_pipe2)
])

# duration

def duration_category(X, short=180, med=400):
	return (
		X
		.assign(duration_cat=np.select([X.duration.lt(short),
									    X.duration.between(short, med, inclusive="left")],
									   ["short", "medium"],
									   default="long"))
		.drop(columns="duration")
	)

class RBFPercentileSimilarity(BaseEstimator, TransformerMixin):
	def __init__(self, variables=None, percentiles=[0.25, 0.5, 0.75], gamma=0.1):
		self.variables = variables
		self.percentiles = percentiles
		self.gamma = gamma


	def fit(self, X, y=None):
		if not self.variables:
			self.variables = X.select_dtypes(include="number").columns.to_list()

		self.reference_values_ = {
			col: (
				X
				.loc[:, col]
				.quantile(self.percentiles)
				.values
				.reshape(-1, 1)
			)
			for col in self.variables
		}

		return self


	def transform(self, X):
		objects = []
		for col in self.variables:
			columns = [f"{col}_rbf_{int(percentile * 100)}" for percentile in self.percentiles]
			obj = pd.DataFrame(
				data=rbf_kernel(X.loc[:, [col]], Y=self.reference_values_[col], gamma=self.gamma),
				columns=columns
			)
			objects.append(obj)
		return pd.concat(objects, axis=1)
   

def is_over(X, value=1000):
    return (
        X
        .assign(**{
            f"duration_over_{value}": X.duration.ge(value).astype(int)
        })
        .drop(columns='duration')
    )

duration_pipe1 = Pipeline(steps=[
	("rbf", RBFPercentileSimilarity()),
	("scaler", PowerTransformer())
])

duration_pipe2 = Pipeline(steps=[
	("cat", FunctionTransformer(func=duration_category)),
	("encoder", OrdinalEncoder(categories=[["short", "medium", "long"]]))
])

duration_union = FeatureUnion(transformer_list=[
	("part1", duration_pipe1),
	("part2", duration_pipe2),
	("part3", FunctionTransformer(func=is_over)),
	("part4", StandardScaler())
])

duration_transformer = Pipeline(steps=[
	("outliers", Winsorizer(capping_method="iqr", fold=1.5)),
	("imputer", SimpleImputer(strategy="median")),
	("union", duration_union)
])


# total stops

def is_direct(X):
    return X.assign(is_direct_flight = X.total_stops.eq(0).astype(int))

total_stops_transformer = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ("", FunctionTransformer(func=is_direct))
])

# additional information

info_pipe1 = Pipeline(steps=[
    ('grouper', RareLabelEncoder(tol=0.1, n_categories=2, replace_with='Other')),
    ('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

def have_info(X):
    return X.assign(additional_info=X.additional_info.ne('No Info').astype(int))

info_union = FeatureUnion(transformer_list=[
    ('part1', info_pipe1),
    ('part2', FunctionTransformer(func=have_info))
])

info_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="constant", fill_value="unknown")),
	("union", info_union)
])

# column transformer


column_transformer = ColumnTransformer(transformers=[
	("air", air_transformer, ["airline"]),
	("doj", doj_transformer, ["date_of_journey"]),
	("location", location_transformer, ["source", 'destination']),
	("time", time_transformer, ["dep_time", "arrival_time"]),
	("dur", duration_transformer, ["duration"]),
	("stops", total_stops_transformer, ["total_stops"]),
	("info", info_transformer, ["additional_info"])
], remainder="passthrough")

# feature selector

estimator = RandomForestRegressor(n_estimators=10, max_depth=3, random_state=42)

selector = SelectBySingleFeaturePerformance(
    estimator = estimator,
    scoring = 'r2',
    threshold=0.06
)

# preprocessor

preprocessor = Pipeline(steps=[
    ('ct', column_transformer),
    ('selector', selector)
])

# %%
preprocessor.fit(train.drop(columns='price'), train.price.copy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 preprocessor.fit(train.drop(columns='price'), train.price.copy())
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:469, in Pipeline.fit(self, X, y, **params)
#     426 """Fit the model.
#     427
#     428 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     466     Pipeline with fitted steps.
#     467 """
#     468 routed_params = self._check_method_params(method="fit", props=params)
# --> 469 Xt = self._fit(X, y, routed_params)
#     470 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     471     if self._final_estimator != "passthrough":
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:406, in Pipeline._fit(self, X, y, routed_params)
#     404     cloned_transformer = clone(transformer)
#     405 # Fit or load from cache the current transformer
# --> 406 X, fitted_transformer = fit_transform_one_cached(
#     407     cloned_transformer,
#     408     X,
#     409     y,
#     410     None,
#     411     message_clsname="Pipeline",
#     412     message=self._log_message(step_idx),
#     413     params=routed_params[name],
#     414 )
#     415 # Replace the transformer of the step with the fitted
#     416 # transformer. This is necessary when loading the transformer
#     417 # from the cache.
#     418 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:976, in ColumnTransformer.fit_transform(self, X, y, **params)
#     973 else:
#     974     routed_params = self._get_empty_routing()
# --> 976 result = self._call_func_on_transformers(
#     977     X,
#     978     y,
#     979     _fit_transform_one,
#     980     column_as_labels=False,
#     981     routed_params=routed_params,
#     982 )
#     984 if not result:
#     985     self._update_fitted_transformers([])
#
# File ~/.local/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:885, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     873             extra_args = {}
#     874         jobs.append(
#     875             delayed(func)(
#     876                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     882             )
#     883         )
# --> 885     return Parallel(n_jobs=self.n_jobs)(jobs)
#     887 except ValueError as e:
#     888     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1735, in FeatureUnion.fit_transform(self, X, y, **params)
#    1732             routed_params[name] = Bunch(transform={})
#    1733             routed_params[name].fit = params
# -> 1735 results = self._parallel_func(X, y, _fit_transform_one, routed_params)
#    1736 if not results:
#    1737     # All transformers are None
#    1738     return np.zeros((X.shape[0], 0))
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1757, in FeatureUnion._parallel_func(self, X, y, func, routed_params)
#    1754 self._validate_transformer_weights()
#    1755 transformers = list(self._iter())
# -> 1757 return Parallel(n_jobs=self.n_jobs)(
#    1758     delayed(func)(
#    1759         transformer,
#    1760         X,
#    1761         y,
#    1762         weight,
#    1763         message_clsname="FeatureUnion",
#    1764         message=self._log_message(name, idx, len(transformers)),
#    1765         params=routed_params[name],
#    1766     )
#    1767     for idx, (name, transformer, weight) in enumerate(transformers, 1)
#    1768 )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:533, in Pipeline.fit_transform(self, X, y, **params)
#     490 """Fit the model and transform with the final estimator.
#     491
#     492 Fit all the transformers one after the other and sequentially transform
#    (...)
#     530     Transformed samples.
#     531 """
#     532 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 533 Xt = self._fit(X, y, routed_params)
#     535 last_step = self._final_estimator
#     536 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:406, in Pipeline._fit(self, X, y, routed_params)
#     404     cloned_transformer = clone(transformer)
#     405 # Fit or load from cache the current transformer
# --> 406 X, fitted_transformer = fit_transform_one_cached(
#     407     cloned_transformer,
#     408     X,
#     409     y,
#     410     None,
#     411     message_clsname="Pipeline",
#     412     message=self._log_message(step_idx),
#     413     params=routed_params[name],
#     414 )
#     415 # Replace the transformer of the step with the fitted
#     416 # transformer. This is necessary when loading the transformer
#     417 # from the cache.
#     418 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.12/site-packages/feature_engine/datetime/datetime.py:273, in DatetimeFeatures.fit(self, X, y)
#     271         self._check_index_contains_na(X.index)
#     272     else:
# --> 273         _check_contains_na(X, self.variables_)
#     275 if self.features_to_extract is None:
#     276     self.features_to_extract_ = FEATURES_DEFAULT
#
# File ~/.local/lib/python3.12/site-packages/feature_engine/dataframe_checks.py:268, in _check_contains_na(X, variables)
#     251 """
#     252 Checks if DataFrame contains null values in the selected columns.
#     253
#    (...)
#     264     If the variable(s) contain null values.
#     265 """
#     267 if X[variables].isnull().any().any():
# --> 268     raise ValueError(
#     269         "Some of the variables in the dataset contain NaN. Check and "
#     270         "remove those before using this transformer."
#     271     )
#
# ValueError: Some of the variables in the dataset contain NaN. Check and remove those before using this transformer.

# %%
preprocessor.transform(train.drop(columns='price'))

# %% [markdown]
# #  5. Preprocess Data and Upload to Bucket

# %%
BUCKET_NAME = 'fligh-prices-bucket'
DATA_PREFIX = 'data'

# %%
def get_file_name(name):
    return f'{name}-pre.csv'       # returning the name of preprocess data

# %%
# first we export data then we upload on s3 bucket
# sagemaker wants its target variable first then after any input

def export_data(data, name, pre):
    # split data into X and y subsets
    
    X = data.drop(columns='price')
    y = data.price.copy()
    
    # transformation
    X_pre = pre.transform(X)
    
    # exporting
    file_name = get_file_name(name)
    
    # here we save file into csv format. index=False, header=False this is the expectation of sagemaker
    (
        y
        .to_frame()
        .join(X_pre)
        .to_csv(file_name, index=False, header=False)
    )

# %%
# interaction of python with aws services

def upload_to_bucket(name):
    
    file_name = get_file_name(name)
    
    (
        boto3
        .Session()  # representing the curr working env
        .resource('s3')
        .Bucket(BUCKET_NAME)
        .Object(os.path.join(DATA_PREFIX, f'{name}/{name}.csv')) # which file you wanna save upto this folder
        .upload_file(file_name)
    )

# %%
def export_and_upload_to_bucket(data, name, pre):
    export_data(data, name, pre)
    upload_to_bucket(name)

# %%
export_and_upload_to_bucket(train, 'train', preprocessor)

# %%
export_and_upload_to_bucket(test, 'test', preprocessor)

# %%
export_and_upload_to_bucket(val , 'val' , preprocessor)

# %% [markdown]
# #  6. Model and Hyperparameter Tuning Set-up

# %%
session = sagemaker.Session()
region_name = session.boto_region_name

# %%
# where to save our model => inside s3 bucket
output_path = f's3://{BUCKET_NAME}/model/output'

# %%
xgboost_container = sagemaker.image_uris.retrieve('xgboost', region_name, "1.2-1")
model = Estimator(
    image_uri = xgboost_container,
    role = sagemaker.get_execution_role(),
    instance_count=1,
    instance_type='ml.m4.xlarge',
    volume_size=5,
    output_path = output_path,
    sagemaker_session=session,
    max_run = 300,
    max_wait= 600,
    use_spot_instances=True
)

# %%
model.set_hyperparameters(
    objective='reg:linear',
    num_round=10,
    eta=0.1,
    max_depth=5, 
    subsample=0.7,
    colsample_bytree = 0.7,
    alpha=0.1
)

# %%
hyperparameter_ranges = {
    "eta": ContinuousParameter(0.05, 0.2),
    "alpha": ContinuousParameter(0, 1),
    "max_depth": IntegerParameter(3, 5)
}

# %%
tuner = HyperparameterTuner(
    estimator=model,
    objective_metric_name="validation:rmse",
    hyperparameter_ranges=hyperparameter_ranges,
    strategy="Bayesian",
    objective_type="Minimize"
)

# %% [markdown]
# # 7. Data Channels

# %%
# model ko path dikhana => channel

# %%
def get_data_channel(name):
    bucket_path = f's3://{BUCKET_NAME}/{DATA_PREFIX}/{name}'
    return TrainingInput(bucket_path, content_type='csv')

# %%
train_data_channel = get_data_channel('train')

# %%
val_data_channel = get_data_channel('val')

# %%
data_channel = {
    'train':train_data_channel,
    'validation':val_data_channel
}

# %% [markdown]
# # 8. Train and Tune the Model

# %%
tuner.fit(data_channel)

# %%
tuner.best_estimator()

# %%
# for deploy the model on sagemaker 
# tuner.best_estimator().deploy()

# %% [markdown]
# # 9. Model Evaluation

# %%
with open('xgboost-model', 'rb') as f:
    best_model = pickle.load(f)
    
best_model

# %%
pd.read_csv('train-pre.csv')

# %%
def evaluate_model(name):
    file_name = get_file_name(name)
    data = pd.read_csv(file_name)
    
    X = xgb.DMatrix(data.iloc[:, 1:])   # this is the formate for xgboost model
    y = data.iloc[:,0].copy()
    
    pred = best_model.predict(X)
    
    return r2_score(y, pred)

# %%
evaluate_model('train')

# %%
evaluate_model('val')

# %%
evaluate_model('test')

# %% [markdown]
# - in our case we need sagemaker
